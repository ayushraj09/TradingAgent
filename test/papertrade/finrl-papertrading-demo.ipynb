# %% [markdown]
# Disclaimer: Nothing herein is financial advice, and NOT a recommendation to trade real money. Many platforms exist for simulated trading (paper trading) which can be used for building and developing the methods discussed. Please use common sense and always first consult a professional before trading or investing.

# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/3-Practical/FinRL_PaperTrading_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a >

# %% [markdown]
# # Part 1: Install FinRL

# %%
# Ensure local FinRL package is importable from this workspace
# %pip install -e /Users/ayushraj/Documents/Python/FinRL/FinRL -q

import sys, os
PROJECT_ROOT = '/Users/ayushraj/Documents/Python/FinRL/FinRL'
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import finrl
print('Using finrl from:', os.path.dirname(finrl.__file__))
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using finrl from: /Users/ayushraj/Documents/Python/FinRL/FinRL/finrl

# %%
# !pwd
# Out:
# /Users/ayushraj

# %%
# !cd Documents/Python/FinRL/FinRL

# %%
# !git clone https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Cloning into 'FinRL'...
# remote: Enumerating objects: 13901, done.
# remote: Counting objects: 100% (909/909), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 13901 (delta 875), reused 853 (delta 853), pack-reused 12992 (from 4)
# Receiving objects: 100% (13901/13901), 81.18 MiB | 4.69 MiB/s, done.
# Resolving deltas: 100% (9329/9329), done.

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip uninstall git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: packaging<=24.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wrds) (24.1)
# Requirement already satisfied: pandas<2.3,>=2.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wrds) (2.9.11)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wrds) (2.0.35)
# Requirement already satisfied: numpy>=1.22.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2025.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.15.0)
# Requirement already satisfied: six>=1.5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Requirement already satisfied: swig in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (4.4.0)
# zsh:1: command not found: apt-get
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/pip-req-build-wpikxghw
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/pip-req-build-wpikxghw
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit dcf6bde8d64e1a747673d24dde30dce195bc3cf1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (3.1.60)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/pip-install-jk7o78_c/elegantrl_3603b29db9644a7ea6f650748da65204
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/pip-install-jk7o78_c/elegantrl_3603b29db9644a7ea6f650748da65204
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 7c64395ff4c2b53892fe6f9eaa3b58947136ffc1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jqdatasdk<2,>=1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pandas-market-calendars<6,>=5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (5.1.1)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (0.9.9)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.51.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (1.5.2)
# Requirement already satisfied: selenium<5,>=4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (4.24.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.7.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (3.4.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from finrl==0.3.8) (0.2.58)
# Requirement already satisfied: th in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: numpy in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.26.4)
# Requirement already satisfied: gymnasium in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.2.1)
# Requirement already satisfied: matplotlib in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (3.9.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.9.2)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.10.10)
# Requirement already satisfied: PyYAML==6.0.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (4.0.3)
# Requirement already satisfied: setuptools>=60.9.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.8) (80.9.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.8) (2024.7.4)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.8) (43.0.1)
# Requirement already satisfied: aiodns>=1.1.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.5.0)
# Requirement already satisfied: six in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.35)
# Requirement already satisfied: pymysql>=0.7.6 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.2)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (4.15.0)
# Requirement already satisfied: tzdata in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (2025.2)
# Requirement already satisfied: python-dateutil in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: exchange-calendars>=3.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (4.11.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.23.4)
# Requirement already satisfied: ipython>=3.2.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (8.26.0)
# Requirement already satisfied: pytz>=2014.10 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.12)
# Requirement already satisfied: cvxpy>=1.1.19 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.7.3)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.0.0)
# Requirement already satisfied: click!=8.3.0,>=7.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.1.7)
# Requirement already satisfied: filelock in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.16.1)
# Requirement already satisfied: jsonschema in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf>=3.20.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.20.3)
# Requirement already satisfied: aiohttp_cors in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.8)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: grpcio>=1.42.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.65.1)
# Requirement already satisfied: opencensus in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-prometheus in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.59b0)
# Requirement already satisfied: opentelemetry-proto in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.27.0)
# Requirement already satisfied: prometheus_client>=0.7.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.20.0)
# Requirement already satisfied: smart_open in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.35.4)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (19.0.0)
# Requirement already satisfied: fsspec in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.7)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.5.0)
# Requirement already satisfied: trio~=0.17 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: sortedcontainers in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: exceptiongroup in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: python-dotenv in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.0.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.11)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.2.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.13.0)
# Requirement already satisfied: pycares>=4.9.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.11.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.5)
# Requirement already satisfied: cffi>=1.12 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.16.0)
# Requirement already satisfied: pycparser in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: osqp>=1.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.5)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.9)
# Requirement already satisfied: bottleneck>=1.3.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.6.0)
# Requirement already satisfied: pyluach>=2.3.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (2.3.0)
# Requirement already satisfied: toolz>=1.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (1.1.0)
# Requirement already satisfied: korean_lunar_calendar>=0.3.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: decorator in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.18.0)
# Requirement already satisfied: stack-data in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (3.1.2)
# Requirement already satisfied: opentelemetry-api==1.38.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (0.59b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from opentelemetry-api==1.38.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.38.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (3.23.0)
# Requirement already satisfied: jinja2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from osqp>=1.0.0->cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.5.1)
# Requirement already satisfied: cloudpickle in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from gymnasium->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: networkx in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.3)
# Requirement already satisfied: sympy==1.13.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: opencv-python in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.10.0.84)
# Requirement already satisfied: pygame in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.17.0)
# Requirement already satisfied: psutil in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (6.0.0)
# Requirement already satisfied: tqdm in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.66.4)
# Requirement already satisfied: rich in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.11.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.3)
# Requirement already satisfied: ply<4.0,>=3.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.1.5)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.19.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.71.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.42.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: wrapt in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: niltype<2.0,>=0.3 in /Users/ayushraj/venv-metal/lib/python3.10/site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)

# %% [markdown]
# ## Get the API Keys Ready

# %%
API_KEY = "PKPGA7BQIFZ7UV3V5ZYUWEXPUY"
API_SECRET = "HRvDc53DYAP2gJZbxn71MRCyZYnm5G5PFpCcAbhipf8Y"
API_BASE_URL = 'https://paper-api.alpaca.markets'
data_url = 'wss://data.alpaca.markets'

# %% [markdown]
# ## Import related modules

# %%
from finrl.config_tickers import DOW_30_TICKER
from finrl.config import INDICATORS
from finrl.meta.env_stock_trading.env_stocktrading_np import StockTradingEnv

import numpy as np
import pandas as pd

# %% [markdown]
# ## PPO

# %%
import os
import time
import gym
import numpy as np
import numpy.random as rd
import torch
import torch.nn as nn
from torch import Tensor
from torch.distributions.normal import Normal


class ActorPPO(nn.Module):
    def __init__(self, dims: [int], state_dim: int, action_dim: int):
        super().__init__()
        self.net = build_mlp(dims=[state_dim, *dims, action_dim])
        self.action_std_log = nn.Parameter(torch.zeros((1, action_dim)), requires_grad=True)  # trainable parameter

    def forward(self, state: Tensor) -> Tensor:
        return self.net(state).tanh()  # action.tanh()

    def get_action(self, state: Tensor) -> (Tensor, Tensor):  # for exploration
        action_avg = self.net(state)
        action_std = self.action_std_log.exp()

        dist = Normal(action_avg, action_std)
        action = dist.sample()
        logprob = dist.log_prob(action).sum(1)
        return action, logprob

    def get_logprob_entropy(self, state: Tensor, action: Tensor) -> (Tensor, Tensor):
        action_avg = self.net(state)
        action_std = self.action_std_log.exp()

        dist = Normal(action_avg, action_std)
        logprob = dist.log_prob(action).sum(1)
        entropy = dist.entropy().sum(1)
        return logprob, entropy

    @staticmethod
    def convert_action_for_env(action: Tensor) -> Tensor:
        return action.tanh()


class CriticPPO(nn.Module):
    def __init__(self, dims: [int], state_dim: int, _action_dim: int):
        super().__init__()
        self.net = build_mlp(dims=[state_dim, *dims, 1])

    def forward(self, state: Tensor) -> Tensor:
        return self.net(state)  # advantage value


def build_mlp(dims: [int]) -> nn.Sequential:  # MLP (MultiLayer Perceptron)
    net_list = []
    for i in range(len(dims) - 1):
        net_list.extend([nn.Linear(dims[i], dims[i + 1]), nn.ReLU()])
    del net_list[-1]  # remove the activation of output layer
    return nn.Sequential(*net_list)


class Config:
    def __init__(self, agent_class=None, env_class=None, env_args=None):
        self.env_class = env_class  # env = env_class(**env_args)
        self.env_args = env_args  # env = env_class(**env_args)

        if env_args is None:  # dummy env_args
            env_args = {'env_name': None, 'state_dim': None, 'action_dim': None, 'if_discrete': None}
        self.env_name = env_args['env_name']  # the name of environment. Be used to set 'cwd'.
        self.state_dim = env_args['state_dim']  # vector dimension (feature number) of state
        self.action_dim = env_args['action_dim']  # vector dimension (feature number) of action
        self.if_discrete = env_args['if_discrete']  # discrete or continuous action space

        self.agent_class = agent_class  # agent = agent_class(...)

        '''Arguments for reward shaping'''
        self.gamma = 0.99  # discount factor of future rewards
        self.reward_scale = 1.0  # an approximate target reward usually be closed to 256

        '''Arguments for training'''
        self.gpu_id = int(0)  # `int` means the ID of single GPU, -1 means CPU
        self.net_dims = (64, 32)  # the middle layer dimension of MLP (MultiLayer Perceptron)
        self.learning_rate = 6e-5  # 2 ** -14 ~= 6e-5
        self.soft_update_tau = 5e-3  # 2 ** -8 ~= 5e-3
        self.batch_size = int(128)  # num of transitions sampled from replay buffer.
        self.horizon_len = int(2000)  # collect horizon_len step while exploring, then update network
        self.buffer_size = None  # ReplayBuffer size. Empty the ReplayBuffer for on-policy.
        self.repeat_times = 8.0  # repeatedly update network using ReplayBuffer to keep critic's loss small

        '''Arguments for evaluate'''
        self.cwd = None  # current working directory to save model. None means set automatically
        self.break_step = +np.inf  # break training if 'total_step > break_step'
        self.eval_times = int(32)  # number of times that get episodic cumulative return
        self.eval_per_step = int(2e4)  # evaluate the agent per training steps

    def init_before_training(self):
        if self.cwd is None:  # set cwd (current working directory) for saving model
            self.cwd = f'./{self.env_name}_{self.agent_class.__name__[5:]}'
        os.makedirs(self.cwd, exist_ok=True)


def get_gym_env_args(env, if_print: bool) -> dict:
    if {'unwrapped', 'observation_space', 'action_space', 'spec'}.issubset(dir(env)):  # isinstance(env, gym.Env):
        env_name = env.unwrapped.spec.id
        state_shape = env.observation_space.shape
        state_dim = state_shape[0] if len(state_shape) == 1 else state_shape  # sometimes state_dim is a list

        if_discrete = isinstance(env.action_space, gym.spaces.Discrete)
        if if_discrete:  # make sure it is discrete action space
            action_dim = env.action_space.n
        elif isinstance(env.action_space, gym.spaces.Box):  # make sure it is continuous action space
            action_dim = env.action_space.shape[0]

    env_args = {'env_name': env_name, 'state_dim': state_dim, 'action_dim': action_dim, 'if_discrete': if_discrete}
    print(f"env_args = {repr(env_args)}") if if_print else None
    return env_args


def kwargs_filter(function, kwargs: dict) -> dict:
    import inspect
    sign = inspect.signature(function).parameters.values()
    sign = {val.name for val in sign}
    common_args = sign.intersection(kwargs.keys())
    return {key: kwargs[key] for key in common_args}  # filtered kwargs


def build_env(env_class=None, env_args=None):
    if env_class.__module__ == 'gym.envs.registration':  # special rule
        env = env_class(id=env_args['env_name'])
    else:
        env = env_class(**kwargs_filter(env_class.__init__, env_args.copy()))
    for attr_str in ('env_name', 'state_dim', 'action_dim', 'if_discrete'):
        setattr(env, attr_str, env_args[attr_str])
    return env


class AgentBase:
    def __init__(self, net_dims: [int], state_dim: int, action_dim: int, gpu_id: int = 0, args: Config = Config()):
        self.state_dim = state_dim
        self.action_dim = action_dim

        self.gamma = args.gamma
        self.batch_size = args.batch_size
        self.repeat_times = args.repeat_times
        self.reward_scale = args.reward_scale
        self.soft_update_tau = args.soft_update_tau

        self.states = None  # assert self.states == (1, state_dim)
        self.device = torch.device(f"cuda:{gpu_id}" if (torch.cuda.is_available() and (gpu_id >= 0)) else "cpu")

        act_class = getattr(self, "act_class", None)
        cri_class = getattr(self, "cri_class", None)
        self.act = self.act_target = act_class(net_dims, state_dim, action_dim).to(self.device)
        self.cri = self.cri_target = cri_class(net_dims, state_dim, action_dim).to(self.device) \
            if cri_class else self.act

        self.act_optimizer = torch.optim.Adam(self.act.parameters(), args.learning_rate)
        self.cri_optimizer = torch.optim.Adam(self.cri.parameters(), args.learning_rate) \
            if cri_class else self.act_optimizer

        self.criterion = torch.nn.SmoothL1Loss()

    @staticmethod
    def optimizer_update(optimizer, objective: Tensor):
        optimizer.zero_grad()
        objective.backward()
        optimizer.step()

    @staticmethod
    def soft_update(target_net: torch.nn.Module, current_net: torch.nn.Module, tau: float):
        for tar, cur in zip(target_net.parameters(), current_net.parameters()):
            tar.data.copy_(cur.data * tau + tar.data * (1.0 - tau))


class AgentPPO(AgentBase):
    def __init__(self, net_dims: [int], state_dim: int, action_dim: int, gpu_id: int = 0, args: Config = Config()):
        self.if_off_policy = False
        self.act_class = getattr(self, "act_class", ActorPPO)
        self.cri_class = getattr(self, "cri_class", CriticPPO)
        AgentBase.__init__(self, net_dims, state_dim, action_dim, gpu_id, args)

        self.ratio_clip = getattr(args, "ratio_clip", 0.25)  # `ratio.clamp(1 - clip, 1 + clip)`
        self.lambda_gae_adv = getattr(args, "lambda_gae_adv", 0.95)  # could be 0.80~0.99
        self.lambda_entropy = getattr(args, "lambda_entropy", 0.01)  # could be 0.00~0.10
        self.lambda_entropy = torch.tensor(self.lambda_entropy, dtype=torch.float32, device=self.device)

    def explore_env(self, env, horizon_len: int) -> [Tensor]:
        states = torch.zeros((horizon_len, self.state_dim), dtype=torch.float32).to(self.device)
        actions = torch.zeros((horizon_len, self.action_dim), dtype=torch.float32).to(self.device)
        logprobs = torch.zeros(horizon_len, dtype=torch.float32).to(self.device)
        rewards = torch.zeros(horizon_len, dtype=torch.float32).to(self.device)
        dones = torch.zeros(horizon_len, dtype=torch.bool).to(self.device)

        ary_state = self.states[0]

        get_action = self.act.get_action
        convert = self.act.convert_action_for_env
        for i in range(horizon_len):
            state = torch.as_tensor(ary_state, dtype=torch.float32, device=self.device)
            action, logprob = [t.squeeze(0) for t in get_action(state.unsqueeze(0))[:2]]

            ary_action = convert(action).detach().cpu().numpy()
            ary_state, reward, done, _, _ = env.step(ary_action)
            if done:
                ary_state, _ = env.reset()

            states[i] = state
            actions[i] = action
            logprobs[i] = logprob
            rewards[i] = reward
            dones[i] = done

        self.states[0] = ary_state
        rewards = (rewards * self.reward_scale).unsqueeze(1)
        undones = (1 - dones.type(torch.float32)).unsqueeze(1)
        return states, actions, logprobs, rewards, undones

    def update_net(self, buffer) -> [float]:
        with torch.no_grad():
            states, actions, logprobs, rewards, undones = buffer
            buffer_size = states.shape[0]

            '''get advantages reward_sums'''
            bs = 2 ** 10  # set a smaller 'batch_size' when out of GPU memory.
            values = [self.cri(states[i:i + bs]) for i in range(0, buffer_size, bs)]
            values = torch.cat(values, dim=0).squeeze(1)  # values.shape == (buffer_size, )

            advantages = self.get_advantages(rewards, undones, values)  # advantages.shape == (buffer_size, )
            reward_sums = advantages + values  # reward_sums.shape == (buffer_size, )
            del rewards, undones, values

            advantages = (advantages - advantages.mean()) / (advantages.std(dim=0) + 1e-5)
        assert logprobs.shape == advantages.shape == reward_sums.shape == (buffer_size,)

        '''update network'''
        obj_critics = 0.0
        obj_actors = 0.0

        update_times = int(buffer_size * self.repeat_times / self.batch_size)
        assert update_times >= 1
        for _ in range(update_times):
            indices = torch.randint(buffer_size, size=(self.batch_size,), requires_grad=False)
            state = states[indices]
            action = actions[indices]
            logprob = logprobs[indices]
            advantage = advantages[indices]
            reward_sum = reward_sums[indices]

            value = self.cri(state).squeeze(1)  # critic network predicts the reward_sum (Q value) of state
            obj_critic = self.criterion(value, reward_sum)
            self.optimizer_update(self.cri_optimizer, obj_critic)

            new_logprob, obj_entropy = self.act.get_logprob_entropy(state, action)
            ratio = (new_logprob - logprob.detach()).exp()
            surrogate1 = advantage * ratio
            surrogate2 = advantage * ratio.clamp(1 - self.ratio_clip, 1 + self.ratio_clip)
            obj_surrogate = torch.min(surrogate1, surrogate2).mean()

            obj_actor = obj_surrogate + obj_entropy.mean() * self.lambda_entropy
            self.optimizer_update(self.act_optimizer, -obj_actor)

            obj_critics += obj_critic.item()
            obj_actors += obj_actor.item()
        a_std_log = getattr(self.act, 'a_std_log', torch.zeros(1)).mean()
        return obj_critics / update_times, obj_actors / update_times, a_std_log.item()

    def get_advantages(self, rewards: Tensor, undones: Tensor, values: Tensor) -> Tensor:
        advantages = torch.empty_like(values)  # advantage value

        masks = undones * self.gamma
        horizon_len = rewards.shape[0]

        next_state = torch.tensor(self.states, dtype=torch.float32).to(self.device)
        next_value = self.cri(next_state).detach()[0, 0]

        advantage = 0  # last_gae_lambda
        for t in range(horizon_len - 1, -1, -1):
            delta = rewards[t] + masks[t] * next_value - values[t]
            advantages[t] = advantage = delta + masks[t] * self.lambda_gae_adv * advantage
            next_value = values[t]
        return advantages


class PendulumEnv(gym.Wrapper):  # a demo of custom gym env
    def __init__(self):
        gym.logger.set_level(40)  # Block warning
        gym_env_name = "Pendulum-v0" if gym.__version__ < '0.18.0' else "Pendulum-v1"
        super().__init__(env=gym.make(gym_env_name))

        '''the necessary env information when you design a custom env'''
        self.env_name = gym_env_name  # the name of this env.
        self.state_dim = self.observation_space.shape[0]  # feature number of state
        self.action_dim = self.action_space.shape[0]  # feature number of action
        self.if_discrete = False  # discrete action or continuous action

    def reset(self) -> np.ndarray:  # reset the agent in env
        resetted_env, _ = self.env.reset()
        return resetted_env

    def step(self, action: np.ndarray) -> (np.ndarray, float, bool, dict):  # agent interacts in env
        # We suggest that adjust action space to (-1, +1) when designing a custom env.
        state, reward, done, info_dict, _ = self.env.step(action * 2)
        return state.reshape(self.state_dim), float(reward), done, info_dict

    
def train_agent(args: Config):
    args.init_before_training()

    env = build_env(args.env_class, args.env_args)
    agent = args.agent_class(args.net_dims, args.state_dim, args.action_dim, gpu_id=args.gpu_id, args=args)

    new_env, _ = env.reset()
    agent.states = new_env[np.newaxis, :]

    evaluator = Evaluator(eval_env=build_env(args.env_class, args.env_args),
                          eval_per_step=args.eval_per_step,
                          eval_times=args.eval_times,
                          cwd=args.cwd)
    torch.set_grad_enabled(False)
    while True: # start training
        buffer_items = agent.explore_env(env, args.horizon_len)

        torch.set_grad_enabled(True)
        logging_tuple = agent.update_net(buffer_items)
        torch.set_grad_enabled(False)

        evaluator.evaluate_and_save(agent.act, args.horizon_len, logging_tuple)
        if (evaluator.total_step > args.break_step) or os.path.exists(f"{args.cwd}/stop"):
            torch.save(agent.act.state_dict(), args.cwd + '/actor.pth')
            break  # stop training when reach `break_step` or `mkdir cwd/stop`


def render_agent(env_class, env_args: dict, net_dims: [int], agent_class, actor_path: str, render_times: int = 8):
    env = build_env(env_class, env_args)

    state_dim = env_args['state_dim']
    action_dim = env_args['action_dim']
    agent = agent_class(net_dims, state_dim, action_dim, gpu_id=-1)
    actor = agent.act

    print(f"| render and load actor from: {actor_path}")
    actor.load_state_dict(torch.load(actor_path, map_location=lambda storage, loc: storage))
    for i in range(render_times):
        cumulative_reward, episode_step = get_rewards_and_steps(env, actor, if_render=True)
        print(f"|{i:4}  cumulative_reward {cumulative_reward:9.3f}  episode_step {episode_step:5.0f}")

        
class Evaluator:
    def __init__(self, eval_env, eval_per_step: int = 1e4, eval_times: int = 8, cwd: str = '.'):
        self.cwd = cwd
        self.env_eval = eval_env
        self.eval_step = 0
        self.total_step = 0
        self.start_time = time.time()
        self.eval_times = eval_times  # number of times that get episodic cumulative return
        self.eval_per_step = eval_per_step  # evaluate the agent per training steps

        self.recorder = []
        print(f"\n| `step`: Number of samples, or total training steps, or running times of `env.step()`."
              f"\n| `time`: Time spent from the start of training to this moment."
              f"\n| `avgR`: Average value of cumulative rewards, which is the sum of rewards in an episode."
              f"\n| `stdR`: Standard dev of cumulative rewards, which is the sum of rewards in an episode."
              f"\n| `avgS`: Average of steps in an episode."
              f"\n| `objC`: Objective of Critic network. Or call it loss function of critic network."
              f"\n| `objA`: Objective of Actor network. It is the average Q value of the critic network."
              f"\n| {'step':>8}  {'time':>8}  | {'avgR':>8}  {'stdR':>6}  {'avgS':>6}  | {'objC':>8}  {'objA':>8}")
            
    def evaluate_and_save(self, actor, horizon_len: int, logging_tuple: tuple):
        self.total_step += horizon_len
        if self.eval_step + self.eval_per_step > self.total_step:
            return
        self.eval_step = self.total_step

        rewards_steps_ary = [get_rewards_and_steps(self.env_eval, actor) for _ in range(self.eval_times)]
        rewards_steps_ary = np.array(rewards_steps_ary, dtype=np.float32)
        avg_r = rewards_steps_ary[:, 0].mean()  # average of cumulative rewards
        std_r = rewards_steps_ary[:, 0].std()  # std of cumulative rewards
        avg_s = rewards_steps_ary[:, 1].mean()  # average of steps in an episode

        used_time = time.time() - self.start_time
        self.recorder.append((self.total_step, used_time, avg_r))
        
        print(f"| {self.total_step:8.2e}  {used_time:8.0f}  "
              f"| {avg_r:8.2f}  {std_r:6.2f}  {avg_s:6.0f}  "
              f"| {logging_tuple[0]:8.2f}  {logging_tuple[1]:8.2f}")


def get_rewards_and_steps(env, actor, if_render: bool = False) -> (float, int):  # cumulative_rewards and episode_steps
    device = next(actor.parameters()).device  # net.parameters() is a Python generator.

    state, _ = env.reset()
    episode_steps = 0
    cumulative_returns = 0.0  # sum of rewards in an episode
    for episode_steps in range(12345):
        tensor_state = torch.as_tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        tensor_action = actor(tensor_state)
        action = tensor_action.detach().cpu().numpy()[0]  # not need detach(), because using torch.no_grad() outside
        state, reward, done, _, _ = env.step(action)
        cumulative_returns += reward

        if if_render:
            env.render()
        if done:
            break
    return cumulative_returns, episode_steps + 1

# %% [markdown]
# ## DRL Agent Class

# %%
# IMPORTANT: Run this cell AFTER creating paper_trading_erl but BEFORE calling .run()
# This patches the trade method to add debug output and fix threading issues

def add_debug_to_paper_trading(paper_trading_instance):
    """Add debug output and fix threading in paper trading instance"""
    import functools
    original_trade = paper_trading_instance.trade
    
    def trade_with_debug(self):
        """Wrapped trade method with debug output"""
        state = self.get_state()
        
        if self.drl_lib == 'elegantrl':
            with torch.no_grad():
                s_tensor = torch.as_tensor((state,), device=self.device)
                a_tensor = self.act(s_tensor)  
                action = a_tensor.detach().cpu().numpy()[0]  
            action = (action * self.max_stock).astype(int)
        elif self.drl_lib == 'rllib':
            action = self.agent.compute_single_action(state)
        elif self.drl_lib == 'stable_baselines3':
            action = self.model.predict(state)[0]
        else:
            raise ValueError('The DRL library input is NOT supported yet.')
        
        # DEBUG OUTPUT
        action_max = np.max(action)
        action_min = np.min(action)
        action_mean = np.mean(np.abs(action))
        min_action = 5
        sell_indices = np.where(action < -min_action)[0]
        buy_indices = np.where(action > min_action)[0]
        
        print(f"\n🔍 TRADE DEBUG:")
        print(f"   Action range: [{action_min:.2f}, {action_max:.2f}], Mean(abs): {action_mean:.2f}")
        print(f"   Sell signals (action < -{min_action}): {len(sell_indices)}")
        print(f"   Buy signals (action > {min_action}): {len(buy_indices)}")
        if len(sell_indices) > 0:
            sell_dict = {self.stockUniverse[i]: action[i] for i in sell_indices}
            print(f"   📉 SELL signals: {sell_dict}")
        if len(buy_indices) > 0:
            buy_dict = {self.stockUniverse[i]: action[i] for i in buy_indices}
            print(f"   📈 BUY signals: {buy_dict}")
        print(f"   💵 Cash: ${self.cash:.2f}, Turbulence: {self.turbulence_bool}")
        
        # Original trade logic with FIXED threading
        self.stocks_cd += 1
        if self.turbulence_bool == 0:
            min_action = 8
            threads = []
            for index in np.where(action < -min_action)[0]:
                sell_num_shares = min(self.stocks[index], -action[index])
                qty = abs(int(sell_num_shares))
                respSO = []
                # FIX: Use lambda with default parameter to fix closure issue
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'sell', respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)
                self.cash = float(self.alpaca.get_account().cash)
                self.stocks_cd[index] = 0
            
            for x in threads:
                x.join()

            threads = []
            for index in np.where(action > min_action)[0]:
                if self.cash < 0:
                    tmp_cash = 0
                else:
                    tmp_cash = self.cash
                buy_num_shares = min(tmp_cash // self.price[index], abs(int(action[index])))
                if (buy_num_shares != buy_num_shares):
                    qty = 0
                else:
                    qty = abs(int(buy_num_shares))
                qty = abs(int(buy_num_shares))
                respSO = []
                # FIX: Use lambda with default parameter to fix closure issue
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'buy', respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)
                self.cash = float(self.alpaca.get_account().cash)
                self.stocks_cd[index] = 0

            for x in threads:
                x.join()
        else:
            print("⚠️  High turbulence - selling all positions")
            threads = []
            positions = self.alpaca.list_positions()
            for position in positions:
                if(position.side == 'long'):
                    orderSide = 'sell'
                else:
                    orderSide = 'buy'
                qty = abs(int(float(position.qty)))
                respSO = []
                # FIX: Use lambda with default parameter to fix closure issue
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, sym=position.symbol, side=orderSide: self.submitOrder(q, sym, side, respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)

            for x in threads:
                x.join()
            
            self.stocks_cd[:] = 0
    
    # Bind the method to the instance
    import types
    paper_trading_instance.trade = types.MethodType(trade_with_debug, paper_trading_instance)
    print("✅ Debug output and threading fix applied to paper_trading_erl instance")

print("📝 Instructions:")
print("   1. Create paper_trading_erl instance")
print("   2. Run: add_debug_to_paper_trading(paper_trading_erl)")
print("   3. Then call: paper_trading_erl.run()")
# Out:
# 📝 Instructions:
#    1. Create paper_trading_erl instance
#    2. Run: add_debug_to_paper_trading(paper_trading_erl)
#    3. Then call: paper_trading_erl.run()

# %%
from __future__ import annotations

import torch
# from elegantrl.agents import AgentA2C

MODELS = {"ppo": AgentPPO}
OFF_POLICY_MODELS = ["ddpg", "td3", "sac"]
ON_POLICY_MODELS = ["ppo"]
# MODEL_KWARGS = {x: config.__dict__[f"{x.upper()}_PARAMS"] for x in MODELS.keys()}

# NOISE = {
#     "normal": NormalActionNoise,
#     "ornstein_uhlenbeck": OrnsteinUhlenbeckActionNoise,
# }


class DRLAgent:
    """Implementations of DRL algorithms
    Attributes
    ----------
        env: gym environment class
            user-defined class
    Methods
    -------
        get_model()"
            setup DRL algorithms
        train_model()
            train DRL algorithms in a train dataset
            and output the trained model
        DRL_prediction()
            make a prediction in a test dataset and get results
    """

    def __init__(self, env, price_array, tech_array, turbulence_array):
        self.env = env
        self.price_array = price_array
        self.tech_array = tech_array
        self.turbulence_array = turbulence_array

    def get_model(self, model_name, model_kwargs):
        env_config = {
            "price_array": self.price_array,
            "tech_array": self.tech_array,
            "turbulence_array": self.turbulence_array,
            "if_train": True,
        }
        environment = self.env(config=env_config)
        env_args = {'config': env_config,
              'env_name': environment.env_name,
              'state_dim': environment.state_dim,
              'action_dim': environment.action_dim,
              'if_discrete': False}
        agent = MODELS[model_name]
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")
        model = Config(agent_class=agent, env_class=self.env, env_args=env_args)
        model.if_off_policy = model_name in OFF_POLICY_MODELS
        if model_kwargs is not None:
            try:
                model.learning_rate = model_kwargs["learning_rate"]
                model.batch_size = model_kwargs["batch_size"]
                model.gamma = model_kwargs["gamma"]
                model.seed = model_kwargs["seed"]
                model.net_dims = model_kwargs["net_dimension"]
                model.target_step = model_kwargs["target_step"]
                model.eval_gap = model_kwargs["eval_gap"]
                model.eval_times = model_kwargs["eval_times"]
            except BaseException:
                raise ValueError(
                    "Fail to read arguments, please check 'model_kwargs' input."
                )
        return model

    def train_model(self, model, cwd, total_timesteps=5000):
        model.cwd = cwd
        model.break_step = total_timesteps
        train_agent(model)

    @staticmethod
    def DRL_prediction(model_name, cwd, net_dimension, environment):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")
        agent_class = MODELS[model_name]
        environment.env_num = 1
        agent = agent_class(net_dimension, environment.state_dim, environment.action_dim)
        actor = agent.act
        # load agent
        try:  
            cwd = cwd + '/actor.pth'
            print(f"| load actor from: {cwd}")
            actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))
            act = actor
            device = agent.device
        except BaseException:
            raise ValueError("Fail to load agent!")

        # test on the testing env
        _torch = torch
        state, _ = environment.reset()
        episode_returns = []  # the cumulative_return / initial_account
        episode_total_assets = [environment.initial_total_asset]
        with _torch.no_grad():
            for i in range(environment.max_step):
                s_tensor = _torch.as_tensor((state,), device=device)
                a_tensor = act(s_tensor)  # action_tanh = act.forward()
                action = (
                    a_tensor.detach().cpu().numpy()[0]
                )  # not need detach(), because with torch.no_grad() outside
                state, reward, done, _, _ = environment.step(action)

                total_asset = (
                    environment.amount
                    + (
                        environment.price_ary[environment.day] * environment.stocks
                    ).sum()
                )
                episode_total_assets.append(total_asset)
                episode_return = total_asset / environment.initial_total_asset
                episode_returns.append(episode_return)
                if done:
                    break
        print("Test Finished!")
        # return episode total_assets on testing data
        print("episode_return", episode_return)
        return episode_total_assets

# %% [markdown]
# ## Train & Test Functions

# %%
from __future__ import annotations

from finrl.meta.data_processor import DataProcessor

def train(
    start_date,
    end_date,
    ticker_list,
    data_source,
    time_interval,
    technical_indicator_list,
    drl_lib,
    env,
    model_name,
    if_vix=True,
    **kwargs,
):
    # download data
    dp = DataProcessor(data_source, **kwargs)
    data = dp.download_data(ticker_list, start_date, end_date, time_interval)
    data = dp.clean_data(data)
    data = dp.add_technical_indicator(data, technical_indicator_list)
    if if_vix:
        data = dp.add_vix(data)
    else:
        data = dp.add_turbulence(data)
    price_array, tech_array, turbulence_array = dp.df_to_array(data, if_vix)
    env_config = {
        "price_array": price_array,
        "tech_array": tech_array,
        "turbulence_array": turbulence_array,
        "if_train": True,
    }
    env_instance = env(config=env_config)

    # read parameters
    cwd = kwargs.get("cwd", "./" + str(model_name))

    if drl_lib == "elegantrl":
        DRLAgent_erl = DRLAgent
        break_step = kwargs.get("break_step", 1e6)
        erl_params = kwargs.get("erl_params")
        agent = DRLAgent_erl(
            env=env,
            price_array=price_array,
            tech_array=tech_array,
            turbulence_array=turbulence_array,
        )
        model = agent.get_model(model_name, model_kwargs=erl_params)
        trained_model = agent.train_model(
            model=model, cwd=cwd, total_timesteps=break_step
        )

# %%
from __future__ import annotations

from finrl.config import INDICATORS
from finrl.config import RLlib_PARAMS
from finrl.config import TEST_END_DATE
from finrl.config import TEST_START_DATE
from finrl.config_tickers import DOW_30_TICKER

def test(
    start_date,
    end_date,
    ticker_list,
    data_source,
    time_interval,
    technical_indicator_list,
    drl_lib,
    env,
    model_name,
    if_vix=True,
    **kwargs,
):

    # import data processor
    from finrl.meta.data_processor import DataProcessor

    # fetch data
    dp = DataProcessor(data_source, **kwargs)
    data = dp.download_data(ticker_list, start_date, end_date, time_interval)
    data = dp.clean_data(data)
    data = dp.add_technical_indicator(data, technical_indicator_list)

    if if_vix:
        data = dp.add_vix(data)
    else:
        data = dp.add_turbulence(data)
    price_array, tech_array, turbulence_array = dp.df_to_array(data, if_vix)

    env_config = {
        "price_array": price_array,
        "tech_array": tech_array,
        "turbulence_array": turbulence_array,
        "if_train": False,
    }
    env_instance = env(config=env_config)

    # load elegantrl needs state dim, action dim and net dim
    net_dimension = kwargs.get("net_dimension", 2**7)
    cwd = kwargs.get("cwd", "./" + str(model_name))
    print("price_array: ", len(price_array))

    if drl_lib == "elegantrl":
        DRLAgent_erl = DRLAgent
        episode_total_assets = DRLAgent_erl.DRL_prediction(
            model_name=model_name,
            cwd=cwd,
            net_dimension=net_dimension,
            environment=env_instance,
        )
        return episode_total_assets

# %% [markdown]
# ## Import Dow Jones 30 Symbols

# %%
ticker_list = DOW_30_TICKER
action_dim = len(DOW_30_TICKER)
action_dim
# Out:
# 30

# %%
print(ticker_list)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
print(INDICATORS)
# Out:
# ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']

# %% [markdown]
# ## Calculate the DRL state dimension manually for paper trading

# %%
# amount + (turbulence, turbulence_bool) + (price, shares, cd (holding time)) * stock_dim + tech_dim
state_dim = 1 + 2 + 3 * action_dim + len(INDICATORS) * action_dim

# %%
state_dim
# Out:
# 333

# %%
env = StockTradingEnv

# %% [markdown]
# ## Show the data

# %% [markdown]
# ### Step 1. Pick a data source

# %%
DP = DataProcessor(data_source = 'alpaca',
                 API_KEY = API_KEY, 
                 API_SECRET = API_SECRET, 
                 API_BASE_URL = API_BASE_URL
                 )
# Out:
# Alpaca successfully connected

# %% [markdown]
# ### Step 2. Get ticker list, Set start date and end date, specify the data frequency

# %%
data = DP.download_data(start_date = '2025-05-04', 
                       end_date = '2025-05-08',
                       ticker_list = ticker_list, 
                       time_interval= '1Min')

# %%
data['timestamp'].nunique()
# Out:
# 1560

# %%
data.head()
# Out:
#                   timestamp     close    high     low  trade_count      open  \
# 0 2025-05-05 09:30:00-04:00  203.2000  203.47  202.95      16463.0  203.1000
# 1 2025-05-05 09:31:00-04:00  203.7400  204.10  203.23       5510.0  203.2521
# 2 2025-05-05 09:32:00-04:00  203.5000  203.89  203.36       2345.0  203.7200
# 3 2025-05-05 09:33:00-04:00  202.9899  203.82  202.89       3529.0  203.4300
# 4 2025-05-05 09:34:00-04:00  202.8500  203.28  202.79       3195.0  202.9400
#
#       volume        vwap   tic
# 0  1038481.0  203.075218  AAPL
# 1   332033.0  203.740059  AAPL
# 2   146123.0  203.562359  AAPL
# 3   213630.0  203.371542  AAPL
# 4   203959.0  203.013009  AAPL

# %%
# Export downloaded data to CSV for validity check
if data is not None:
    data.to_csv('papertrading_downloaded_data.csv', index=False)
    print('✅ Data exported to papertrading_downloaded_data.csv')
else:
    print('⚠️ No data available to export')
# Out:
# ✅ Data exported to papertrading_downloaded_data.csv

# %% [markdown]
# ### Step 3. Data Cleaning & Feature Engineering

# %%
data = DP.clean_data(data)
data = DP.add_technical_indicator(data, INDICATORS)
data = DP.add_vix(data)
# Out:
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!

# %%
data.shape
# Out:
# (46800, 16)

# %%
# Export downloaded data to CSV for validity check
if data is not None:
    data.to_csv('alpaca_training.csv', index=False)
    print('✅ Data exported to alpaca_training.csv')
else:
    print('⚠️ No data available to export')
# Out:
# ✅ Data exported to alpaca_training.csv

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46800 entries, 0 to 46799
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     46800 non-null  datetime64[ns, America/New_York]
#  1   open          46800 non-null  float64
#  2   high          46800 non-null  float64
#  3   low           46800 non-null  float64
#  4   close         46800 non-null  float64
#  5   volume        46800 non-null  float64
#  6   tic           46800 non-null  object
#  7   macd          46800 non-null  float64
#  8   boll_ub       46770 non-null  float64
#  9   boll_lb       46770 non-null  float64
#  10  rsi_30        46770 non-null  float64
#  11  cci_30        46770 non-null  float64
#  12  dx_30         46761 non-null  float64
#  13  close_30_sma  46800 non-null  float64
#  14  close_60_sma  46800 non-null  float64
#  15  VIXY          46800 non-null  float64
# dtypes: datetime64[ns, America/New_York](1), float64(14), object(1)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Step 4. Transform to numpy array

# %%
price_array, tech_array, turbulence_array = DP.df_to_array(data, if_vix=True)

# %% [markdown]
# # Part 2: Train the agent

# %% [markdown]
# ## Train

# %%
ERL_PARAMS = {"learning_rate": 3e-6,"batch_size": 2048,"gamma":  0.985,
        "seed":312,"net_dimension":[128,64], "target_step":20000, "eval_gap":30,
        "eval_times":1} 
env = StockTradingEnv
#if you want to use larger datasets (change to longer period), and it raises error, 
#please try to increase "target_step". It should be larger than the episode steps.

# %% [markdown]
# start_date = '2025-01-01',
#                        end_date = '2025-10-01',

# %%
train(start_date = '2025-10-20',
      end_date = '2025-10-30',
      ticker_list = ticker_list, 
      data_source = 'alpaca',
      time_interval= '1Min', 
      technical_indicator_list= INDICATORS,
      drl_lib='elegantrl', 
      env=env,
      model_name='ppo',
      if_vix=True, 
      API_KEY = API_KEY, 
      API_SECRET = API_SECRET, 
      API_BASE_URL = API_BASE_URL,
      erl_params=ERL_PARAMS,
      cwd='./papertrading_erl', #current_working_dir
      break_step=1e5)
# Out:
# Alpaca successfully connected
# empty
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
#
# | `step`: Number of samples, or total training steps, or running times of `env.step()`.
# | `time`: Time spent from the start of training to this moment.
# | `avgR`: Average value of cumulative rewards, which is the sum of rewards in an episode.
# | `stdR`: Standard dev of cumulative rewards, which is the sum of rewards in an episode.
# | `avgS`: Average of steps in an episode.
# | `objC`: Objective of Critic network. Or call it loss function of critic network.
# | `objA`: Objective of Actor network. It is the average Q value of the critic network.
# |     step      time  |     avgR    stdR    avgS  |     objC      objA
# | 2.00e+04         6  |     5.83    0.00    3509  |     0.22      0.41
# | 4.00e+04        12  |     7.45    0.00    3509  |     0.22      0.41
# | 6.00e+04        18  |     7.32    0.00    3509  |     0.18      0.41
# | 8.00e+04        24  |     7.91    0.00    3509  |     0.16      0.42
# | 1.00e+05        30  |     9.02    0.00    3509  |     0.20      0.39

# %% [markdown]
# ## Test

# %%
account_value_erl=test(start_date = '2025-11-01', 
                      end_date = '2025-11-03',
                      ticker_list = ticker_list, 
                      data_source = 'alpaca',
                      time_interval= '1Min', 
                      technical_indicator_list= INDICATORS,
                      drl_lib='elegantrl', 
                      env=env, 
                      model_name='ppo',
                      if_vix=True, 
                      API_KEY = API_KEY, 
                      API_SECRET = API_SECRET, 
                      API_BASE_URL = API_BASE_URL,
                      cwd='./papertrading_erl',
                      net_dimension = ERL_PARAMS['net_dimension'])
# Out:
# Alpaca successfully connected
# empty
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
# price_array:  390
# | load actor from: ./papertrading_erl/actor.pth
# Test Finished!
# episode_return 0.9971974600555306
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_76265/2834462138.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))

# %% [markdown]
#     def get_state(self):
#         price, tech, turbulence = self.alpaca_processor.fetch_latest_data(
#             ticker_list=self.stockUniverse,
#             time_interval='1Min',
#             tech_indicator_list=self.tech_indicator_list
#         )
#         turbulence_bool = 1 if turbulence >= self.turbulence_thresh else 0
#
#         turbulence = (self.sigmoid_sign(turbulence, self.turbulence_thresh) * 2 ** -5).astype(np.float32)
#
#         tech = tech * 2 ** -7
#         positions = self.alpaca.list_positions()
#         stocks = [0] * len(self.stockUniverse)
#         for position in positions:
#             ind = self.stockUniverse.index(position.symbol)
#             stocks[ind] = ( abs(int(float(position.qty))))
#
#         stocks = np.asarray(stocks, dtype = float)
#         cash = float(self.alpaca.get_account().cash)
#         self.cash = cash
#         self.stocks = stocks
#         self.turbulence_bool = turbulence_bool
#         self.price = price
#
#         amount = np.array(self.cash * (2 ** -12), dtype=np.float32)
#         scale = np.array(2 ** -6, dtype=np.float32)
#         state = np.hstack((amount,
#                     turbulence,
#                     self.turbulence_bool,
#                     price * scale,
#                     self.stocks * scale,
#                     self.stocks_cd,
#                     tech,
#                     )).astype(np.float32)
#         state[np.isnan(state)] = 0.0
#         state[np.isinf(state)] = 0.0
#         return state

# %% [markdown]
# After tuning well, retrain on the training and testing sets

# %%
train(start_date = '2025-10-01', 
      end_date = '2025-10-30',
      ticker_list = ticker_list, 
      data_source = 'alpaca',
      time_interval= '1Min', 
      technical_indicator_list= INDICATORS,
      drl_lib='elegantrl', 
      env=env, 
      model_name='ppo',
      if_vix=True, 
      API_KEY = API_KEY, 
      API_SECRET = API_SECRET, 
      API_BASE_URL = API_BASE_URL,
      erl_params=ERL_PARAMS,
      cwd='./papertrading_erl_retrain',
      break_step=2e5)
# Out:
# Alpaca successfully connected
# empty
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
# Data cleaning started
# align start and end dates
# produce full timestamp index
# Start processing tickers
# ticker list complete
# Start concat and rename
# Data clean finished!
#
# | `step`: Number of samples, or total training steps, or running times of `env.step()`.
# | `time`: Time spent from the start of training to this moment.
# | `avgR`: Average value of cumulative rewards, which is the sum of rewards in an episode.
# | `stdR`: Standard dev of cumulative rewards, which is the sum of rewards in an episode.
# | `avgS`: Average of steps in an episode.
# | `objC`: Objective of Critic network. Or call it loss function of critic network.
# | `objA`: Objective of Actor network. It is the average Q value of the critic network.
# |     step      time  |     avgR    stdR    avgS  |     objC      objA
# | 2.00e+04         7  |    18.70    0.00    8579  |     0.38      0.40
# | 4.00e+04        14  |    17.75    0.00    8579  |     0.37      0.41
# | 6.00e+04        20  |    16.71    0.00    8579  |     0.23      0.41
# | 8.00e+04        27  |    12.91    0.00    8579  |     0.35      0.42
# | 1.00e+05        34  |    12.57    0.00    8579  |     0.24      0.43
# | 1.20e+05        40  |     8.87    0.00    8579  |     0.20      0.40
# | 1.40e+05        47  |     8.53    0.00    8579  |     0.28      0.42
# | 1.60e+05        54  |    10.82    0.00    8579  |     0.20      0.41
# | 1.80e+05        61  |     7.77    0.00    8579  |     0.10      0.40
# | 2.00e+05        67  |    10.88    0.00    8579  |     0.26      0.41

# %% [markdown]
# # Part 3: Deploy the agent

# %% [markdown]
# ## Setup Alpaca Paper trading environment

# %%
import datetime
import threading
from finrl.meta.data_processors.processor_alpaca import AlpacaProcessor
import alpaca_trade_api as tradeapi
import time
import pandas as pd
import numpy as np
import torch
import gym
from datetime import timezone

class AlpacaPaperTrading():

    def __init__(self, ticker_list, time_interval, drl_lib, agent, cwd, net_dim, 
                 state_dim, action_dim, API_KEY, API_SECRET, 
                 API_BASE_URL, tech_indicator_list, turbulence_thresh=500, 
                 max_stock=1e2, latency=None):
        self.API_KEY = API_KEY
        self.API_SECRET = API_SECRET
        self.API_BASE_URL = API_BASE_URL

        self.alpaca_processor = AlpacaProcessor(API_KEY=API_KEY, 
                                           API_SECRET=API_SECRET, 
                                           API_BASE_URL=API_BASE_URL)
        
        #load agent
        self.drl_lib = drl_lib
        if agent =='ppo':
            if drl_lib == 'elegantrl':              
                agent_class = AgentPPO
                agent = agent_class(net_dim, state_dim, action_dim)
                actor = agent.act
                # load agent
                try:  
                    cwd = cwd + '/actor.pth'
                    print(f"| load actor from: {cwd}")
                    actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))
                    self.act = actor
                    self.device = agent.device
                except BaseException:
                    raise ValueError("Fail to load agent!")
                        
            elif drl_lib == 'rllib':
                from ray.rllib.agents import ppo
                from ray.rllib.agents.ppo.ppo import PPOTrainer
                
                config = ppo.DEFAULT_CONFIG.copy()
                config['env'] = StockEnvEmpty
                config["log_level"] = "WARN"
                config['env_config'] = {'state_dim':state_dim,
                            'action_dim':action_dim,}
                trainer = PPOTrainer(env=StockEnvEmpty, config=config)
                trainer.restore(cwd)
                try:
                    trainer.restore(cwd)
                    self.agent = trainer
                    print("Restoring from checkpoint path", cwd)
                except:
                    raise ValueError('Fail to load agent!')
                    
            elif drl_lib == 'stable_baselines3':
                from stable_baselines3 import PPO
                
                try:
                    #load agent
                    self.model = PPO.load(cwd)
                    print("Successfully load model", cwd)
                except:
                    raise ValueError('Fail to load agent!')
                    
            else:
                raise ValueError('The DRL library input is NOT supported yet. Please check your input.')
               
        else:
            raise ValueError('Agent input is NOT supported yet.')
            
            
            
        #connect to Alpaca trading API
        try:
            self.alpaca = tradeapi.REST(API_KEY,API_SECRET,API_BASE_URL, 'v2')
        except:
            raise ValueError('Fail to connect Alpaca. Please check account info and internet connection.')
        
        #read trading time interval
        if time_interval == '1s':
            self.time_interval = 1
        elif time_interval == '5s':
            self.time_interval = 5
        elif time_interval == '1Min':
            self.time_interval = 60
        elif time_interval == '5Min':
            self.time_interval = 60 * 5
        elif time_interval == '15Min':
            self.time_interval = 60 * 15
        else:
            raise ValueError('Time interval input is NOT supported yet.')
        
        #read trading settings
        self.tech_indicator_list = tech_indicator_list
        self.turbulence_thresh = turbulence_thresh
        self.max_stock = max_stock 
        
        #initialize account
        self.stocks = np.asarray([0] * len(ticker_list)) #stocks holding
        self.stocks_cd = np.zeros_like(self.stocks) 
        self.cash = None #cash record 
        self.stocks_df = pd.DataFrame(self.stocks, columns=['stocks'], index = ticker_list)
        self.asset_list = []
        self.price = np.asarray([0] * len(ticker_list))
        self.stockUniverse = ticker_list
        self.turbulence_bool = 0
        self.equities = []
        
    def test_latency(self, test_times = 10): 
        total_time = 0
        for i in range(0, test_times):
            time0 = time.time()
            self.get_state()
            time1 = time.time()
            temp_time = time1 - time0
            total_time += temp_time
        latency = total_time/test_times
        print('latency for data processing: ', latency)
        return latency
        
    def run(self):
        orders = self.alpaca.list_orders(status="open")
        for order in orders:
          self.alpaca.cancel_order(order.id)
    
        # Wait for market to open.
        print("Waiting for market to open...")
        self.awaitMarketOpen()
        print("Market opened.")

        while True:

          # Figure out when the market will close so we can prepare to sell beforehand.
          clock = self.alpaca.get_clock()
          closingTime = clock.next_close.replace(tzinfo=timezone.utc).timestamp()
          currTime = clock.timestamp.replace(tzinfo=timezone.utc).timestamp()
          self.timeToClose = closingTime - currTime
    
          if(self.timeToClose < (60)):
            # Close all positions when 1 minutes til market close.
            print("Market closing soon. Stop trading.")
            break
            
          else:
            self.trade()
            last_equity = float(self.alpaca.get_account().last_equity)
            cur_time = time.time()
            self.equities.append([cur_time,last_equity])
            time.sleep(self.time_interval)
            
    def awaitMarketOpen(self):
        isOpen = self.alpaca.get_clock().is_open
        while(not isOpen):
          clock = self.alpaca.get_clock()
          openingTime = clock.next_open.replace(tzinfo=datetime.timezone.utc).timestamp()
          currTime = clock.timestamp.replace(tzinfo=datetime.timezone.utc).timestamp()
          timeToOpen = int((openingTime - currTime) / 60)
          print(str(timeToOpen) + " minutes til market open.")
          time.sleep(60)
          isOpen = self.alpaca.get_clock().is_open
    
    def trade(self):
        state = self.get_state()
        
        if self.drl_lib == 'elegantrl':
            with torch.no_grad():
                s_tensor = torch.as_tensor((state,), device=self.device)
                a_tensor = self.act(s_tensor)  
                action = a_tensor.detach().cpu().numpy()[0]  
            action = (action * self.max_stock).astype(int)
            
        elif self.drl_lib == 'rllib':
            action = self.agent.compute_single_action(state)
        
        elif self.drl_lib == 'stable_baselines3':
            action = self.model.predict(state)[0]
            
        else:
            raise ValueError('The DRL library input is NOT supported yet. Please check your input.')
        
        self.stocks_cd += 1
        if self.turbulence_bool == 0:
            min_action = 10  # stock_cd
            threads = []
            # SELL orders
            for index in np.where(action < -min_action)[0]:  # sell_index:
                sell_num_shares = min(self.stocks[index], -action[index])
                qty =  abs(int(sell_num_shares))
                respSO = []
                # FIX: Use lambda with default parameter to capture current values
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'sell', respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)
                self.cash = float(self.alpaca.get_account().cash)
                self.stocks_cd[index] = 0
            
            for x in threads:
                x.join()

            threads = []
            # BUY orders
            for index in np.where(action > min_action)[0]:  # buy_index:
                if self.cash < 0:
                    tmp_cash = 0
                else:
                    tmp_cash = self.cash
                buy_num_shares = min(tmp_cash // self.price[index], abs(int(action[index])))
                if (buy_num_shares != buy_num_shares): # if buy_num_change = nan
                    qty = 0 # set to 0 quantity
                else:
                    qty = abs(int(buy_num_shares))
                respSO = []
                # FIX: Use lambda with default parameter to capture current values
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'buy', respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)
                self.cash = float(self.alpaca.get_account().cash)
                self.stocks_cd[index] = 0

            for x in threads:
                x.join()
                
        else:  # sell all when turbulence
            print("⚠️  High turbulence - selling all positions")
            threads = []
            positions = self.alpaca.list_positions()
            for position in positions:
                if(position.side == 'long'):
                    orderSide = 'sell'
                else:
                    orderSide = 'buy'
                qty = abs(int(float(position.qty)))
                respSO = []
                # FIX: Use lambda with default parameter to capture current values
                tSubmitOrder = threading.Thread(
                    target=lambda q=qty, sym=position.symbol, side=orderSide: self.submitOrder(q, sym, side, respSO)
                )
                tSubmitOrder.start()
                threads.append(tSubmitOrder)

            for x in threads:
                x.join()
            
            self.stocks_cd[:] = 0
            
    
    def get_state(self):
        price, tech, turbulence = self.alpaca_processor.fetch_latest_data(
            ticker_list=self.stockUniverse, 
            time_interval='1Min',
            tech_indicator_list=self.tech_indicator_list
        )
        turbulence_bool = 1 if turbulence >= self.turbulence_thresh else 0
        
        turbulence = (self.sigmoid_sign(turbulence, self.turbulence_thresh) * 2 ** -5).astype(np.float32)
        
        tech = tech * 2 ** -7
        positions = self.alpaca.list_positions()
        stocks = [0] * len(self.stockUniverse)
        for position in positions:
            ind = self.stockUniverse.index(position.symbol)
            stocks[ind] = ( abs(int(float(position.qty))))
        
        stocks = np.asarray(stocks, dtype = float)
        cash = float(self.alpaca.get_account().cash)
        self.cash = cash
        self.stocks = stocks
        self.turbulence_bool = turbulence_bool 
        self.price = price
        
        amount = np.array(self.cash * (2 ** -12), dtype=np.float32)
        scale = np.array(2 ** -6, dtype=np.float32)
        state = np.hstack((amount,
                    turbulence,
                    self.turbulence_bool,
                    price * scale,
                    self.stocks * scale,
                    self.stocks_cd,
                    tech,
                    )).astype(np.float32)
        state[np.isnan(state)] = 0.0
        state[np.isinf(state)] = 0.0
        return state
        
    def submitOrder(self, qty, stock, side, resp):
        if(qty > 0):
          try:
            self.alpaca.submit_order(stock, qty, side, "market", "day")
            print("Market order of | " + str(qty) + " " + stock + " " + side + " | completed.")
            resp.append(True)
          except:
            print("Order of | " + str(qty) + " " + stock + " " + side + " | did not go through.")
            resp.append(False)
        else:
          print("Quantity is 0, order of | " + str(qty) + " " + stock + " " + side + " | not completed.")
          resp.append(True)

    @staticmethod
    def sigmoid_sign(ary, thresh):
        def sigmoid(x):
            return 1 / (1 + np.exp(-x * np.e)) - 0.5

        return sigmoid(ary / thresh) * thresh
    
class StockEnvEmpty(gym.Env):
    #Empty Env used for loading rllib agent
    def __init__(self,config):
      state_dim = config['state_dim']
      action_dim = config['action_dim']
      self.env_num = 1
      self.max_step = 10000
      self.env_name = 'StockEnvEmpty'
      self.state_dim = state_dim  
      self.action_dim = action_dim
      self.if_discrete = False  
      self.target_return = 9999
      self.observation_space = gym.spaces.Box(low=-3000, high=3000, shape=(state_dim,), dtype=np.float32)
      self.action_space = gym.spaces.Box(low=-1, high=1, shape=(action_dim,), dtype=np.float32)
        
    def reset(self):
        return 

    def step(self, actions):
        return

# %% [markdown]
# ## Run Paper trading

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
state_dim
# Out:
# 333

# %%
action_dim
# Out:
# 30

# %% [markdown]
# API_BASE_URL = 'https://paper-api.alpaca.markets'

# %%
# IMPORTANT: Use 29 tickers to match the retrained model dimensions
# The retrained model has 29 actions, so we need to use 29 tickers
# Remove 'DOW' from the original DOW_30_TICKER list to get 29 tickers

TICKER_LIST_29 = [ticker for ticker in DOW_30_TICKER if ticker != 'DOW']
print(f"Using 29 tickers for paper trading: {TICKER_LIST_29}")
print(f"Number of tickers: {len(TICKER_LIST_29)}")

# Update dimensions for 29 tickers
action_dim_29 = len(TICKER_LIST_29)
state_dim_29 = 1 + 2 + 3 * action_dim_29 + len(INDICATORS) * action_dim_29

print(f"Action dimension (29 tickers): {action_dim_29}")
print(f"State dimension (29 tickers): {state_dim_29}")
print(f"Using model from: './papertrading_erl_retrain'")
# Out:
# Using 29 tickers for paper trading: ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS']
# Number of tickers: 29
# Action dimension (29 tickers): 29
# State dimension (29 tickers): 322
# Using model from: './papertrading_erl_retrain'

# %%
# Paper trading with 29 tickers and retrained model
paper_trading_erl = AlpacaPaperTrading(ticker_list = TICKER_LIST_29,  # Use 29 tickers instead of DOW_30_TICKER
                                       time_interval = '1Min', 
                                       drl_lib = 'elegantrl', 
                                       agent = 'ppo', 
                                       cwd = './papertrading_erl_retrain',  # Use retrained model
                                       net_dim = ERL_PARAMS['net_dimension'], 
                                       state_dim = state_dim_29,  # Use 29-ticker state dimension
                                       action_dim= action_dim_29,  # Use 29-ticker action dimension
                                       API_KEY = API_KEY, 
                                       API_SECRET = API_SECRET, 
                                       API_BASE_URL = API_BASE_URL, 
                                       tech_indicator_list = INDICATORS, 
                                       turbulence_thresh=30, 
                                       max_stock=1e2)

print("✅ Paper trading instance created successfully with 29 tickers and retrained model")
print("📊 Configuration:")
print(f"   - Tickers: {len(TICKER_LIST_29)} (excluding DOW)")
print(f"   - Model path: './papertrading_erl_retrain'")
print(f"   - State dimension: {state_dim_29}")
print(f"   - Action dimension: {action_dim_29}")
print("\n🚀 Ready to start paper trading! Call paper_trading_erl.run() when ready.")
# Out:
# | load actor from: ./papertrading_erl_retrain/actor.pth
# ✅ Paper trading instance created successfully with 29 tickers and retrained model
# 📊 Configuration:
#    - Tickers: 29 (excluding DOW)
#    - Model path: './papertrading_erl_retrain'
#    - State dimension: 322
#    - Action dimension: 29
#
# 🚀 Ready to start paper trading! Call paper_trading_erl.run() when ready.
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_6631/2371896842.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))

# %%
# Create a more aggressive paper trading instance
paper_trading_erl = AlpacaPaperTrading(ticker_list = TICKER_LIST_29, 
                                       time_interval = '1Min', 
                                       drl_lib = 'elegantrl', 
                                       agent = 'ppo', 
                                       cwd = './papertrading_erl_retrain',
                                       net_dim = ERL_PARAMS['net_dimension'], 
                                       state_dim = state_dim_29,
                                       action_dim = action_dim_29, 
                                       API_KEY = API_KEY, 
                                       API_SECRET = API_SECRET, 
                                       API_BASE_URL = API_BASE_URL, 
                                       tech_indicator_list = INDICATORS, 
                                       turbulence_thresh=500,  # Much higher threshold to allow trading in volatile conditions
                                       max_stock=1e2)

# Modify the trade method to use a lower minimum action threshold
def trade_with_lower_threshold(self):
    state = self.get_state()
    
    if self.drl_lib == 'elegantrl':
        with torch.no_grad():
            s_tensor = torch.as_tensor((state,), device=self.device)
            a_tensor = self.act(s_tensor)  
            action = a_tensor.detach().cpu().numpy()[0]  
        action = (action * self.max_stock).astype(int)
    elif self.drl_lib == 'rllib':
        action = self.agent.compute_single_action(state)
    elif self.drl_lib == 'stable_baselines3':
        action = self.model.predict(state)[0]
    else:
        raise ValueError('The DRL library input is NOT supported yet.')
    
    # DEBUG OUTPUT
    action_max = np.max(action)
    action_min = np.min(action)
    action_mean = np.mean(np.abs(action))
    min_action = 8  # Lower threshold (was 10)
    sell_indices = np.where(action < -min_action)[0]
    buy_indices = np.where(action > min_action)[0]
    
    print(f"\n🔍 TRADE DEBUG:")
    print(f"   Action range: [{action_min:.2f}, {action_max:.2f}], Mean(abs): {action_mean:.2f}")
    print(f"   Sell signals (action < -{min_action}): {len(sell_indices)}")
    print(f"   Buy signals (action > {min_action}): {len(buy_indices)}")
    if len(sell_indices) > 0:
        sell_dict = {self.stockUniverse[i]: action[i] for i in sell_indices}
        print(f"   📉 SELL signals: {sell_dict}")
    if len(buy_indices) > 0:
        buy_dict = {self.stockUniverse[i]: action[i] for i in buy_indices}
        print(f"   📈 BUY signals: {buy_dict}")
    print(f"   💵 Cash: ${self.cash:.2f}, Turbulence: {self.turbulence_bool}")
    
    # Trading logic with lower threshold
    self.stocks_cd += 1
    if self.turbulence_bool == 0:
        min_action = 5  # Lower threshold for more frequent trading
        threads = []
        for index in np.where(action < -min_action)[0]:  # sell_index
            sell_num_shares = min(self.stocks[index], -action[index])
            qty = abs(int(sell_num_shares))
            respSO = []
            tSubmitOrder = threading.Thread(
                target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'sell', respSO)
            )
            tSubmitOrder.start()
            threads.append(tSubmitOrder)
            self.cash = float(self.alpaca.get_account().cash)
            self.stocks_cd[index] = 0
        
        for x in threads:
            x.join()
        
        threads = []
        for index in np.where(action > min_action)[0]:  # buy_index
            if self.cash < 0:
                tmp_cash = 0
            else:
                tmp_cash = self.cash
            buy_num_shares = min(tmp_cash // self.price[index], abs(int(action[index])))
            if (buy_num_shares != buy_num_shares):
                qty = 0
            else:
                qty = abs(int(buy_num_shares))
            qty = abs(int(buy_num_shares))
            respSO = []
            tSubmitOrder = threading.Thread(
                target=lambda q=qty, s=self.stockUniverse[index]: self.submitOrder(q, s, 'buy', respSO)
            )
            tSubmitOrder.start()
            threads.append(tSubmitOrder)
            self.cash = float(self.alpaca.get_account().cash)
            self.stocks_cd[index] = 0
        
        for x in threads:
            x.join()
    else:
        print("⚠️  High turbulence - selling all positions")
        threads = []
        positions = self.alpaca.list_positions()
        for position in positions:
            if(position.side == 'long'):
                orderSide = 'sell'
            else:
                orderSide = 'buy'
            qty = abs(int(float(position.qty)))
            respSO = []
            tSubmitOrder = threading.Thread(
                target=lambda q=qty, sym=position.symbol, side=orderSide: self.submitOrder(q, sym, side, respSO)
            )
            tSubmitOrder.start()
            threads.append(tSubmitOrder)
        
        for x in threads:
            x.join()
        
        self.stocks_cd[:] = 0

# Replace the trade method with our more aggressive version
import types
paper_trading_erl.trade = types.MethodType(trade_with_lower_threshold, paper_trading_erl)

print("✅ Created more aggressive paper trading instance with:")
print("   - Higher turbulence threshold (500)")
print("   - Lower minimum action threshold (5 instead of 10)")
print("   - Using retrained model from './papertrading_erl_retrain'")
print("\n🚀 Ready to trade! Run paper_trading_erl.run() to start trading")
# Out:
# | load actor from: ./papertrading_erl_retrain/actor.pth
# ✅ Created more aggressive paper trading instance with:
#    - Higher turbulence threshold (500)
#    - Lower minimum action threshold (5 instead of 10)
#    - Using retrained model from './papertrading_erl_retrain'
#
# 🚀 Ready to trade! Run paper_trading_erl.run() to start trading
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_6631/2371896842.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))

# %%
# Create a completely fresh paper trading instance with robust error handling
import numpy as np
import threading
import torch
import types

# Create new instance 
paper_trading_erl_robust = AlpacaPaperTrading(ticker_list = TICKER_LIST_29, 
                                              time_interval = '1Min', 
                                              drl_lib = 'elegantrl', 
                                              agent = 'ppo', 
                                              cwd = './papertrading_erl_retrain',
                                              net_dim = ERL_PARAMS['net_dimension'], 
                                              state_dim = state_dim_29,
                                              action_dim = action_dim_29, 
                                              API_KEY = API_KEY, 
                                              API_SECRET = API_SECRET, 
                                              API_BASE_URL = API_BASE_URL, 
                                              tech_indicator_list = INDICATORS, 
                                              turbulence_thresh=500,
                                              max_stock=1e2)

def safe_trade_method(self):
    """Completely safe trade method with no NaN issues"""
    state = self.get_state()
    
    if self.drl_lib == 'elegantrl':
        with torch.no_grad():
            s_tensor = torch.as_tensor((state,), device=self.device)
            a_tensor = self.act(s_tensor)  
            action = a_tensor.detach().cpu().numpy()[0]  
        action = (action * self.max_stock).astype(int)
    elif self.drl_lib == 'rllib':
        action = self.agent.compute_single_action(state)
    elif self.drl_lib == 'stable_baselines3':
        action = self.model.predict(state)[0]
    else:
        raise ValueError('The DRL library input is NOT supported yet.')
    
    print(f"\n🔍 TRADE DEBUG:")
    print(f"   Action range: [{np.min(action):.2f}, {np.max(action):.2f}], Mean(abs): {np.mean(np.abs(action)):.2f}")
    print(f"   💵 Cash: ${self.cash:.2f}, Turbulence: {self.turbulence_bool}")
    
    # Execute trades with complete safety
    try:
        self.stocks_cd += 1
        if self.turbulence_bool == 0:
            min_action = 5
            
            # Sell first (to free up cash)
            sell_orders = 0
            for index in np.where(action < -min_action)[0]:
                try:
                    if self.stocks[index] > 0:  # Only sell if we have shares
                        sell_qty = min(int(self.stocks[index]), int(-action[index]))
                        if sell_qty > 0:
                            self.submitOrder(sell_qty, self.stockUniverse[index], 'sell', [])
                            sell_orders += 1
                            self.stocks_cd[index] = 0
                except Exception as e:
                    print(f"Sell error for {self.stockUniverse[index]}: {str(e)}")
                    continue
            
            # Update cash after sells
            try:
                self.cash = float(self.alpaca.get_account().cash)
            except:
                pass
            
            # Buy with updated cash (only if we have positive cash)
            buy_orders = 0
            if self.cash > 100:  # Only buy if we have sufficient cash
                for index in np.where(action > min_action)[0]:
                    try:
                        current_price = self.price[index]
                        if current_price > 0 and self.cash > current_price:
                            max_shares = int(self.cash / current_price)
                            desired_shares = int(abs(action[index]))
                            buy_qty = min(max_shares, desired_shares)
                            
                            if buy_qty > 0:
                                self.submitOrder(buy_qty, self.stockUniverse[index], 'buy', [])
                                buy_orders += 1
                                self.stocks_cd[index] = 0
                                self.cash -= (buy_qty * current_price)  # Conservative estimate
                    except Exception as e:
                        print(f"Buy error for {self.stockUniverse[index]}: {str(e)}")
                        continue
            
            print(f"   📊 Executed: {sell_orders} sells, {buy_orders} buys")
            
        else:
            print("⚠️ High turbulence - liquidating positions")
            try:
                positions = self.alpaca.list_positions()
                for position in positions:
                    try:
                        qty = int(float(position.qty))
                        if qty > 0:
                            orderSide = 'sell' if position.side == 'long' else 'buy'
                            self.submitOrder(qty, position.symbol, orderSide, [])
                    except Exception as e:
                        print(f"Liquidation error for {position.symbol}: {str(e)}")
                        continue
            except Exception as e:
                print(f"Error during liquidation: {str(e)}")
            
            self.stocks_cd[:] = 0
            
    except Exception as e:
        print(f"Critical trade error: {str(e)}")
        return

# Attach the safe trade method
paper_trading_erl_robust.trade = types.MethodType(safe_trade_method, paper_trading_erl_robust)

print("✅ Created fresh paper trading instance with completely safe trade method")
print("🚀 Starting paper trading...")
# Out:
# | load actor from: ./papertrading_erl_retrain/actor.pth
# ✅ Created fresh paper trading instance with completely safe trade method
# 🚀 Starting paper trading...
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_6631/2371896842.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(cwd, map_location=lambda storage, loc: storage))

# %%
# Start trading
paper_trading_erl_robust.run()
# Out:
# Waiting for market to open...
# Market opened.
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-39.00, 56.00], Mean(abs): 17.31
#    💵 Cash: $-4133.98, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.41
#    💵 Cash: $1001284.37, Turbulence: 0
# Market order of | 81 AMGN buy | completed.
# Market order of | 80 CSCO buy | completed.
# Market order of | 91 CVX buy | completed.
# Market order of | 94 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 8 INTC buy | completed.
# Market order of | 21 JNJ buy | completed.
# Market order of | 47 KO buy | completed.
# Market order of | 59 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 82 MSFT buy | completed.
# Market order of | 31 CRM buy | completed.
#    📊 Executed: 0 sells, 12 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 95.00], Mean(abs): 66.93
#    💵 Cash: $1001159.14, Turbulence: 0
# Market order of | 82 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 87 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 95 HON buy | completed.
# Market order of | 18 INTC buy | completed.
# Market order of | 36 KO buy | completed.
# Market order of | 68 MCD buy | completed.
# Market order of | 93 MRK buy | completed.
# Market order of | 88 MSFT buy | completed.
# Market order of | 16 CRM buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 95.00], Mean(abs): 66.72
#    💵 Cash: $1000958.45, Turbulence: 0
# Market order of | 81 AMGN buy | completed.
# Market order of | 82 CSCO buy | completed.
# Market order of | 88 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 95 HON buy | completed.
# Market order of | 15 INTC buy | completed.
# Market order of | 7 JNJ buy | completed.
# Market order of | 37 KO buy | completed.
# Market order of | 66 MCD buy | completed.
# Market order of | 93 MRK buy | completed.
# Market order of | 86 MSFT buy | completed.
# Market order of | 17 CRM buy | completed.
#    📊 Executed: 0 sells, 12 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.03
#    💵 Cash: $1000807.22, Turbulence: 0
# Market order of | 79 AMGN buy | completed.
# Market order of | 82 CSCO buy | completed.
# Market order of | 88 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 16 INTC buy | completed.
# Market order of | 8 JNJ buy | completed.
# Market order of | 34 KO buy | completed.
# Market order of | 66 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 86 MSFT buy | completed.
# Market order of | 12 CRM buy | completed.
#    📊 Executed: 0 sells, 12 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.48
#    💵 Cash: $1000455.18, Turbulence: 0
# Market order of | 79 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 89 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 10 JNJ buy | completed.
# Market order of | 32 KO buy | completed.
# Market order of | 67 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 86 MSFT buy | completed.
# Market order of | 9 CRM buy | completed.
#    📊 Executed: 0 sells, 12 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.41
#    💵 Cash: $1000263.79, Turbulence: 0
# Market order of | 77 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 89 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 11 JNJ buy | completed.
# Market order of | 29 KO buy | completed.
# Market order of | 66 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 86 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.45
#    💵 Cash: $1000105.72, Turbulence: 0
# Market order of | 75 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 88 CVX buy | completed.
# Market order of | 93 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 11 JNJ buy | completed.
# Market order of | 27 KO buy | completed.
# Market order of | 66 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 87 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 96.00], Mean(abs): 67.59
#    💵 Cash: $999942.54, Turbulence: 0
# Market order of | 72 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 89 CVX buy | completed.
# Market order of | 92 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 10 JNJ buy | completed.
# Market order of | 24 KO buy | completed.
# Market order of | 66 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 87 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.00
#    💵 Cash: $999711.30, Turbulence: 0
# Market order of | 70 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 89 CVX buy | completed.
# Market order of | 92 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 18 INTC buy | completed.
# Market order of | 10 JNJ buy | completed.
# Market order of | 21 KO buy | completed.
# Market order of | 68 MCD buy | completed.
# Market order of | 94 MRK buy | completed.
# Market order of | 88 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.31
#    💵 Cash: $999528.93, Turbulence: 0
# Market order of | 67 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 89 CVX buy | completed.
# Market order of | 92 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 9 JNJ buy | completed.
# Market order of | 19 KO buy | completed.
# Market order of | 69 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 88 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.38
#    💵 Cash: $999294.39, Turbulence: 0
# Market order of | 65 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 88 CVX buy | completed.
# Market order of | 92 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 7 JNJ buy | completed.
# Market order of | 15 KO buy | completed.
# Market order of | 70 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 89 MSFT buy | completed.
#    📊 Executed: 0 sells, 11 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.62
#    💵 Cash: $999066.98, Turbulence: 0
# Market order of | 63 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 88 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 11 KO buy | completed.
# Market order of | 72 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 89 MSFT buy | completed.
#    📊 Executed: 0 sells, 10 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.72
#    💵 Cash: $998855.75, Turbulence: 0
# Market order of | 61 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 87 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 8 KO buy | completed.
# Market order of | 74 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 89 MSFT buy | completed.
#    📊 Executed: 0 sells, 10 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.76
#    💵 Cash: $998639.99, Turbulence: 0
# Market order of | 60 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 86 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 18 INTC buy | completed.
# Market order of | 76 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 90 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 68.72
#    💵 Cash: $998424.74, Turbulence: 0
# Market order of | 57 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 85 CVX buy | completed.
# Market order of | 90 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 17 INTC buy | completed.
# Market order of | 78 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 91 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 97.00], Mean(abs): 67.48
#    💵 Cash: $920632.39, Turbulence: 0
# Market order of | 49 AMGN buy | completed.
# Market order of | 81 CSCO buy | completed.
# Market order of | 81 CVX buy | completed.
# Market order of | 89 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 15 INTC buy | completed.
# Market order of | 77 MCD buy | completed.
# Market order of | 95 MRK buy | completed.
# Market order of | 90 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 69.59
#    💵 Cash: $997619.85, Turbulence: 0
# Market order of | 53 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 83 CVX buy | completed.
# Market order of | 90 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 16 INTC buy | completed.
# Market order of | 81 MCD buy | completed.
# Market order of | 96 MRK buy | completed.
# Market order of | 92 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 70.07
#    💵 Cash: $997887.06, Turbulence: 0
# Market order of | 51 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 82 CVX buy | completed.
# Market order of | 90 GS buy | completed.
# Market order of | 97 HON buy | completed.
# Market order of | 16 INTC buy | completed.
# Market order of | 82 MCD buy | completed.
# Market order of | 96 MRK buy | completed.
# Market order of | 92 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 70.62
#    💵 Cash: $997903.19, Turbulence: 0
# Market order of | 50 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 81 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 15 INTC buy | completed.
# Market order of | 84 MCD buy | completed.
# Market order of | 96 MRK buy | completed.
# Market order of | 93 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 70.90
#    💵 Cash: $997677.19, Turbulence: 0
# Market order of | 48 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 80 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 14 INTC buy | completed.
# Market order of | 85 MCD buy | completed.
# Market order of | 96 MRK buy | completed.
# Market order of | 93 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 71.45
#    💵 Cash: $997491.34, Turbulence: 0
# Market order of | 47 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 79 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 14 INTC buy | completed.
# Market order of | 86 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 93 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 71.59
#    💵 Cash: $997439.82, Turbulence: 0
# Market order of | 45 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 78 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 13 INTC buy | completed.
# Market order of | 87 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 94 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 71.79
#    💵 Cash: $997271.94, Turbulence: 0
# Market order of | 44 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 77 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 12 INTC buy | completed.
# Market order of | 88 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 94 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 72.00
#    💵 Cash: $996888.42, Turbulence: 0
# Market order of | 42 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 75 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 12 INTC buy | completed.
# Market order of | 89 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 94 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 72.07
#    💵 Cash: $996702.39, Turbulence: 0
# Market order of | 41 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 73 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 11 INTC buy | completed.
# Market order of | 89 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 95 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 72.21
#    💵 Cash: $996533.05, Turbulence: 0
# Market order of | 39 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 72 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 10 INTC buy | completed.
# Market order of | 90 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 95 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 72.24
#    💵 Cash: $996364.24, Turbulence: 0
# Market order of | 39 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 71 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 11 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 95 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.62
#    💵 Cash: $996194.19, Turbulence: 0
# Market order of | 39 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 71 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 13 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 96 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.66
#    💵 Cash: $995983.19, Turbulence: 0
# Market order of | 38 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 70 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 15 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 96 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.86
#    💵 Cash: $995991.94, Turbulence: 0
# Market order of | 39 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 68 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 18 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 96 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.00
#    💵 Cash: $995947.96, Turbulence: 0
# Market order of | 38 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 67 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 20 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.24
#    💵 Cash: $995826.28, Turbulence: 0
# Market order of | 39 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 66 CVX buy | completed.
# Market order of | 91 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 22 INTC buy | completed.
# Market order of | 91 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.62
#    💵 Cash: $995729.70, Turbulence: 0
# Market order of | 40 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 65 CVX buy | completed.
# Market order of | 90 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 26 INTC buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.83
#    💵 Cash: $995545.89, Turbulence: 0
# Market order of | 40 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 65 CVX buy | completed.
# Market order of | 89 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 30 INTC buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.07
#    💵 Cash: $995339.74, Turbulence: 0
# Market order of | 41 AMGN buy | completed.
# Market order of | 84 CSCO buy | completed.
# Market order of | 64 CVX buy | completed.
# Market order of | 89 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 33 INTC buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.34
#    💵 Cash: $995177.98, Turbulence: 0
# Market order of | 41 AMGN buy | completed.
# Market order of | 85 CSCO buy | completed.
# Market order of | 64 CVX buy | completed.
# Market order of | 88 GS buy | completed.
# Market order of | 99 HON buy | completed.
# Market order of | 36 INTC buy | completed.
# Market order of | 7 JNJ buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 98 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 0 sells, 10 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 74.34
#    💵 Cash: $994986.04, Turbulence: 0
# Market order of | 40 AMGN buy | completed.
# Market order of | 83 CSCO buy | completed.
# Market order of | 65 CVX buy | completed.
# Market order of | 84 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 41 INTC buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 98 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 74.31
#    💵 Cash: $994809.20, Turbulence: 0
# Market order of | 41 AMGN buy | completed.
# Market order of | 82 CSCO buy | completed.
# Market order of | 65 CVX buy | completed.
# Market order of | 83 GS buy | completed.
# Market order of | 98 HON buy | completed.
# Market order of | 45 INTC buy | completed.
# Market order of | 92 MCD buy | completed.
# Market order of | 97 MRK buy | completed.
# Market order of | 98 MSFT buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 97.00], Mean(abs): 70.76
#    💵 Cash: $774998.41, Turbulence: 0
# Market order of | 9 JNJ sell | completed.
# Market order of | 29 CRM sell | completed.
# Market order of | 43 AMGN buy | completed.
# Market order of | 71 CSCO buy | completed.
# Market order of | 47 CVX buy | completed.
# Market order of | 52 GS buy | completed.
# Market order of | 96 HON buy | completed.
# Market order of | 67 INTC buy | completed.
# Market order of | 27 KO buy | completed.
# Market order of | 85 MCD buy | completed.
# Market order of | 93 MRK buy | completed.
# Market order of | 97 MSFT buy | completed.
#    📊 Executed: 2 sells, 10 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-96.00, 93.00], Mean(abs): 62.59
#    💵 Cash: $437909.43, Turbulence: 0
# Market order of | 20 CRM sell | completed.
# Market order of | 69 AMGN buy | completed.
# Market order of | 45 CSCO buy | completed.
# Market order of | 37 CVX buy | completed.
# Market order of | 67 GS buy | completed.
# Market order of | 92 HON buy | completed.
# Market order of | 56 IBM buy | completed.
# Market order of | 67 INTC buy | completed.
# Market order of | 8 JNJ buy | completed.
# Market order of | 35 KO buy | completed.
# Market order of | 75 MCD buy | completed.
# Market order of | 75 MRK buy | completed.
# Market order of | 93 MSFT buy | completed.
#    📊 Executed: 1 sells, 12 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-95.00, 91.00], Mean(abs): 54.90
#    💵 Cash: $139154.30, Turbulence: 0
# Market order of | 72 AMGN buy | completed.
# Market order of | 53 CSCO buy | completed.
# Market order of | 61 CVX buy | completed.
# Market order of | 69 GS buy | completed.
# Market order of | 91 HON buy | completed.
# Market order of | 83 IBM buy | completed.
# Market order of | 61 INTC buy | completed.
# Market order of | 16 JNJ buy | completed.
# Market order of | 1 KO buy | completed.
#    📊 Executed: 0 sells, 9 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-94.00, 92.00], Mean(abs): 55.17
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-94.00, 93.00], Mean(abs): 56.00
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-95.00, 93.00], Mean(abs): 56.76
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-95.00, 94.00], Mean(abs): 57.66
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-95.00, 94.00], Mean(abs): 58.55
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-96.00, 95.00], Mean(abs): 59.45
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-96.00, 95.00], Mean(abs): 60.17
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-96.00, 95.00], Mean(abs): 61.10
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-96.00, 96.00], Mean(abs): 61.86
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 96.00], Mean(abs): 62.52
#    💵 Cash: $-188.80, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 96.00], Mean(abs): 63.21
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 96.00], Mean(abs): 63.90
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 96.00], Mean(abs): 64.59
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 97.00], Mean(abs): 65.21
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-97.00, 97.00], Mean(abs): 65.90
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 97.00], Mean(abs): 66.55
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 97.00], Mean(abs): 67.28
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 97.00], Mean(abs): 67.76
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 98.00], Mean(abs): 68.21
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 98.00], Mean(abs): 68.83
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 98.00], Mean(abs): 69.34
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 98.00], Mean(abs): 69.79
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-98.00, 98.00], Mean(abs): 70.28
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 70.79
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 71.24
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 98.00], Mean(abs): 71.59
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.00
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.41
#    💵 Cash: $-3784.17, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 72.83
#    💵 Cash: $-3375.08, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.00
#    💵 Cash: $-439.58, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.24
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.55
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 73.72
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.03
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.28
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.59
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.76
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 74.90
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 75.03
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# Started adding Indicators
# Running Loop
# Restore Timestamps
# Finished adding Indicators
#
# 🔍 TRADE DEBUG:
#    Action range: [-99.00, 99.00], Mean(abs): 75.38
#    💵 Cash: $-9814.02, Turbulence: 0
#    📊 Executed: 0 sells, 0 buys
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/common/rest.py:198, in RESTClient._one_request(self, method, url, opts, retry)
#     197 try:
# --> 198     response.raise_for_status()
#     199 except HTTPError as http_error:
#     200     # retry if we hit Rate Limit
#
# File ~/venv-metal/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://data.alpaca.markets/v2/stocks/bars?limit=100&timeframe=1Min&symbols=BA
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[76], line 2
#       1 # Start trading
# ----> 2 paper_trading_erl_robust.run()
#
# Cell In[70], line 151, in AlpacaPaperTrading.run(self)
#     148   break
#     150 else:
# --> 151   self.trade()
#     152   last_equity = float(self.alpaca.get_account().last_equity)
#     153   cur_time = time.time()
#
# Cell In[75], line 25, in safe_trade_method(self)
#      23 def safe_trade_method(self):
#      24     """Completely safe trade method with no NaN issues"""
# ---> 25     state = self.get_state()
#      27     if self.drl_lib == 'elegantrl':
#      28         with torch.no_grad():
#
# Cell In[70], line 258, in AlpacaPaperTrading.get_state(self)
#     257 def get_state(self):
# --> 258     price, tech, turbulence = self.alpaca_processor.fetch_latest_data(
#     259         ticker_list=self.stockUniverse,
#     260         time_interval='1Min',
#     261         tech_indicator_list=self.tech_indicator_list
#     262     )
#     263     turbulence_bool = 1 if turbulence >= self.turbulence_thresh else 0
#     265     turbulence = (self.sigmoid_sign(turbulence, self.turbulence_thresh) * 2 ** -5).astype(np.float32)
#
# File ~/Documents/Python/FinRL/FinRL/finrl/meta/data_processors/processor_alpaca.py:420, in AlpacaProcessor.fetch_latest_data(self, ticker_list, time_interval, tech_indicator_list, limit)
#     415 for tic in ticker_list:
#     416     request_params = StockBarsRequest(
#     417         symbol_or_symbols=[tic], timeframe=TimeFrame.Minute, limit=limit
#     418     )
# --> 420     barset = self.client.get_stock_bars(request_params).df
#     422     if barset.empty:
#     423         continue
#
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/data/historical/stock.py:87, in StockHistoricalDataClient.get_stock_bars(self, request_params)
#      75 def get_stock_bars(
#      76     self, request_params: StockBarsRequest
#      77 ) -> Union[BarSet, RawData]:
#      78     """Returns bar data for an equity or list of equities over a given
#      79     time period and timeframe.
#      80
#    (...)
#      85         Union[BarSet, RawData]: The bar data either in raw or wrapped form
#      86     """
# ---> 87     raw_bars = self._get_marketdata(
#      88         path="/stocks/bars",
#      89         params=request_params.to_request_fields(),
#      90     )
#      92     if self._use_raw_data:
#      93         return raw_bars
#
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/common/rest.py:393, in RESTClient._get_marketdata(self, path, params, page_limit, no_sub_key)
#     390 params["limit"] = actual_limit
#     391 params["page_token"] = page_token
# --> 393 response = self.get(path=path, data=params)
#     395 for k, v in _get_marketdata_entries(response, no_sub_key).items():
#     396     if isinstance(v, list):
#
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/common/rest.py:225, in RESTClient.get(self, path, data, **kwargs)
#     212 def get(
#     213     self, path: str, data: Optional[Union[dict, str]] = None, **kwargs
#     214 ) -> HTTPResult:
#     215     """Performs a single GET request
#     216
#     217     Args:
#    (...)
#     223         dict: The response
#     224     """
# --> 225     return self._request("GET", path, data, **kwargs)
#
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/common/rest.py:131, in RESTClient._request(self, method, path, data, base_url, api_version)
#     129 while retry >= 0:
#     130     try:
# --> 131         return self._one_request(method, url, opts, retry)
#     132     except RetryException:
#     133         time.sleep(self._retry_wait)
#
# File ~/venv-metal/lib/python3.10/site-packages/alpaca/common/rest.py:207, in RESTClient._one_request(self, method, url, opts, retry)
#     204     # raise API error for all other errors
#     205     error = response.text
# --> 207     raise APIError(error, http_error)
#     209 if response.text != "":
#     210     return response.json()
#
# APIError: {"message": "too many requests."}

# %% [markdown]
# API_KEY = "PKPGA7BQIFZ7UV3V5ZYUWEXPUY"
# API_SECRET = "HRvDc53DYAP2gJZbxn71MRCyZYnm5G5PFpCcAbhipf8Y"
# API_BASE_URL = 'https://paper-api.alpaca.markets'

# %%
# !pip show finrl

# %% [markdown]
# # Part 4: Check Portfolio Performance

# %%
import alpaca_trade_api as tradeapi
import pandas_market_calendars as tc
import numpy as np
import pandas as pd
import pytz
import yfinance as yf
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from datetime import datetime as dt
from finrl.plot import backtest_stats
import matplotlib.pyplot as plt
# Out:
# /Users/ayushraj/venv-metal/lib/python3.10/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
def get_trading_days(start, end):
    nyse = tc.get_calendar('NYSE')
    df = nyse.date_range_htf("1D", pd.Timestamp(start), pd.Timestamp(end))
    # df = nyse.sessions_in_range(pd.Timestamp(start),
    #                             pd.Timestamp(end))
    trading_days = []
    for day in df:
        trading_days.append(str(day)[:10])

    return trading_days

def alpaca_history(key, secret, url, start, end):
    api = tradeapi.REST(key, secret, url, 'v2')
    trading_days = get_trading_days(start, end)
    df = pd.DataFrame()
    for day in trading_days:
        #df = df.append(api.get_portfolio_history(date_start = day,timeframe='5Min').df.iloc[:78])
        df= pd.concat([df,api.get_portfolio_history(date_start = day,timeframe='5Min').df.iloc[:78]],ignore_index=True)
        
    equities = df.equity.values
    cumu_returns = equities/equities[0]
    cumu_returns = cumu_returns[~np.isnan(cumu_returns)]
    
    return df, cumu_returns

def DIA_history(start):
    data_df = yf.download(['^DJI'],start=start, interval="5m")
    data_df = data_df.iloc[:]
    baseline_returns = data_df['Adj Close'].values/data_df['Adj Close'].values[0]
    return data_df, baseline_returns

# %% [markdown]
# ## Get cumulative return

# %%
df_erl, cumu_erl = alpaca_history(key=API_KEY, 
                                  secret=API_SECRET, 
                                  url=API_BASE_URL, 
                                  start='2025-10-20', #must be within 1 month
                                  end='2025-10-31') #change the date if error occurs
# Out:
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_64038/1142418273.py:21: RuntimeWarning: divide by zero encountered in divide
#   cumu_returns = equities/equities[0]
# /var/folders/qr/80j1cy4s5q542dmdc5lwzzqc0000gn/T/ipykernel_64038/1142418273.py:21: RuntimeWarning: invalid value encountered in divide
#   cumu_returns = equities/equities[0]

# %%
df_djia, cumu_djia = DIA_history(start='2025-10-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df_djia, cumu_djia = DIA_history(start='2025-10-01')
#
# Cell In[25], line 29, in DIA_history(start)
#      27 data_df = yf.download(['^DJI'],start=start, interval="5m")
#      28 data_df = data_df.iloc[:]
# ---> 29 baseline_returns = data_df['Adj Close'].values/data_df['Adj Close'].values[0]
#      30 return data_df, baseline_returns
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/frame.py:4101, in DataFrame.__getitem__(self, key)
#    4099 if is_single_key:
#    4100     if self.columns.nlevels > 1:
# -> 4101         return self._getitem_multilevel(key)
#    4102     indexer = self.columns.get_loc(key)
#    4103     if is_integer(indexer):
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/frame.py:4159, in DataFrame._getitem_multilevel(self, key)
#    4157 def _getitem_multilevel(self, key):
#    4158     # self.columns is a MultiIndex
# -> 4159     loc = self.columns.get_loc(key)
#    4160     if isinstance(loc, (slice, np.ndarray)):
#    4161         new_columns = self.columns[loc]
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3040, in MultiIndex.get_loc(self, key)
#    3037     return mask
#    3039 if not isinstance(key, tuple):
# -> 3040     loc = self._get_level_indexer(key, level=0)
#    3041     return _maybe_to_slice(loc)
#    3043 keylen = len(key)
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3388         return slice(i, j, step)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#    3395         if isinstance(idx, slice):
#    3396             # test_get_loc_partial_timestamp_multiindex
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2978     return -1
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File ~/venv-metal/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Adj Close'

# %%
df_erl.tail()
# Out:
#      profit_loss  profit_loss_pct     equity
# 775          0.0              0.0  1000000.0
# 776          0.0              0.0  1000000.0
# 777          0.0              0.0  1000000.0
# 778          0.0              0.0  1000000.0
# 779          0.0              0.0  1000000.0

# %%
returns_erl = cumu_erl -1 
returns_dia = cumu_djia - 1
returns_dia = returns_dia[:returns_erl.shape[0]]
print('len of erl return: ', returns_erl.shape[0])
print('len of dia return: ', returns_dia.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 returns_erl = cumu_erl -1
# ----> 2 returns_dia = cumu_djia - 1
#       3 returns_dia = returns_dia[:returns_erl.shape[0]]
#       4 print('len of erl return: ', returns_erl.shape[0])
#
# NameError: name 'cumu_djia' is not defined

# %%
returns_erl
# Out:
# array([inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf])

# %% [markdown]
# ## plot and save

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=1000)
plt.grid()
plt.grid(which='minor', axis='y')
plt.title('Stock Trading (Paper trading)', fontsize=20)
plt.plot(returns_erl, label = 'ElegantRL Agent', color = 'red')
#plt.plot(returns_sb3, label = 'Stable-Baselines3 Agent', color = 'blue' )
#plt.plot(returns_rllib, label = 'RLlib Agent', color = 'green')
plt.plot(returns_dia, label = 'DJIA', color = 'grey')
plt.ylabel('Return', fontsize=16)
plt.xlabel('Year 2021', fontsize=16)
plt.xticks(size = 14)
plt.yticks(size = 14)
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(78))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(6))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=2))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(['','10-19','','10-20',
                                                    '','10-21','','10-22']))
plt.legend(fontsize=10.5)
plt.savefig('papertrading_stock.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 9
#       6 plt.plot(returns_erl, label = 'ElegantRL Agent', color = 'red')
#       7 #plt.plot(returns_sb3, label = 'Stable-Baselines3 Agent', color = 'blue' )
#       8 #plt.plot(returns_rllib, label = 'RLlib Agent', color = 'green')
# ----> 9 plt.plot(returns_dia, label = 'DJIA', color = 'grey')
#      10 plt.ylabel('Return', fontsize=16)
#      11 plt.xlabel('Year 2021', fontsize=16)
#
# NameError: name 'returns_dia' is not defined
